# %%
# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import dnaplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
# Initialize Parts
# K2205003  is orange [1.00, 0.75, 0.17]
pT7 = {'name':'P_lac', 'start':1, 'end':10, 'type':'Promoter', 'opts': {'color':[0.38, 0.82, 0.32]}}
B0034 = {'name':'RBS', 'start':11, 'end':20, 'type':'RBS', 'opts':{'linewidth': 0, 'color':[0.0, 0.0, 0.0]}}
K2205003 = {'name':'tetR', 'start':21, 'end':40, 'type':'CDS', 'opts':{'label': 'tetR', 'fontsize': 8,  'label_y_offset': 0, 'label_x_offset': -2, 'label_style':'italic', 'color':[1.00, 0.75, 0.17]}}
B0010 = {'name':'Term', 'start':41, 'end':55, 'type':'Terminator'}
B0012 = {'name':'Term', 'start':96, 'end':110, 'type':'Terminator'}

# %%
plt.figure(figsize=(4, 2),dpi=300)
gs = gridspec.GridSpec(1, 1)

# Plot of repressilator circuit
ax = plt.subplot(gs[0])
dnaplotlib.plot_sbol_designs([ax], [[pT7, B0034, K2205003, B0010, B0012]])
# Out:
# (84.0, [-0.84, 84.84], [-35, 35])
